# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = '../facial-keypoints-detection/training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 0.0082 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00240, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 0.0019 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00240 to 0.00201, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00201 to 0.00188, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00188
# Epoch 5/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00188
# Epoch 6/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00188 to 0.00184, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 9.7148e-04 - val_loss: 0.0019
#
# Epoch 00007: val_loss did not improve from 0.00184
# Epoch 8/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 8.7968e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00184 to 0.00162, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 7.3633e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00162 to 0.00149, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 6.6298e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00149 to 0.00129, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 5.8857e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00129 to 0.00122, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 5.3088e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00122 to 0.00110, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 253us/step - loss: 4.9279e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00110 to 0.00106, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 265us/step - loss: 4.6190e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00106
# Epoch 15/150
# 1712/1712 [==============================] - 0s 259us/step - loss: 4.3211e-04 - val_loss: 9.9050e-04
#
# Epoch 00015: val_loss improved from 0.00106 to 0.00099, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 264us/step - loss: 4.0384e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss did not improve from 0.00099
# Epoch 17/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 3.9420e-04 - val_loss: 9.3199e-04
#
# Epoch 00017: val_loss improved from 0.00099 to 0.00093, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 3.8698e-04 - val_loss: 9.0329e-04
#
# Epoch 00018: val_loss improved from 0.00093 to 0.00090, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 3.6771e-04 - val_loss: 9.3246e-04
#
# Epoch 00019: val_loss did not improve from 0.00090
# Epoch 20/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 3.4607e-04 - val_loss: 9.2512e-04
#
# Epoch 00020: val_loss did not improve from 0.00090
# Epoch 21/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 3.3416e-04 - val_loss: 8.7385e-04
#
# Epoch 00021: val_loss improved from 0.00090 to 0.00087, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 3.2850e-04 - val_loss: 8.9702e-04
#
# Epoch 00022: val_loss did not improve from 0.00087
# Epoch 23/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 3.1829e-04 - val_loss: 8.4018e-04
#
# Epoch 00023: val_loss improved from 0.00087 to 0.00084, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 3.0290e-04 - val_loss: 9.0463e-04
#
# Epoch 00024: val_loss did not improve from 0.00084
# Epoch 25/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 3.0208e-04 - val_loss: 8.3433e-04
#
# Epoch 00025: val_loss improved from 0.00084 to 0.00083, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 2.9437e-04 - val_loss: 8.6617e-04
#
# Epoch 00026: val_loss did not improve from 0.00083
# Epoch 27/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 2.8525e-04 - val_loss: 8.8028e-04
#
# Epoch 00027: val_loss did not improve from 0.00083
# Epoch 28/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 2.7777e-04 - val_loss: 8.3873e-04
#
# Epoch 00028: val_loss did not improve from 0.00083
# Epoch 29/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 2.7130e-04 - val_loss: 8.6112e-04
#
# Epoch 00029: val_loss did not improve from 0.00083
# Epoch 30/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 2.6877e-04 - val_loss: 8.2676e-04
#
# Epoch 00030: val_loss improved from 0.00083 to 0.00083, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 2.6715e-04 - val_loss: 8.2328e-04
#
# Epoch 00031: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 0s 253us/step - loss: 2.5481e-04 - val_loss: 8.2367e-04
#
# Epoch 00032: val_loss did not improve from 0.00082
# Epoch 33/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 2.4894e-04 - val_loss: 8.3813e-04
#
# Epoch 00033: val_loss did not improve from 0.00082
# Epoch 34/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 2.4327e-04 - val_loss: 8.3351e-04
#
# Epoch 00034: val_loss did not improve from 0.00082
# Epoch 35/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 2.3747e-04 - val_loss: 8.8769e-04
#
# Epoch 00035: val_loss did not improve from 0.00082
# Epoch 36/150
# 1712/1712 [==============================] - 0s 259us/step - loss: 2.4008e-04 - val_loss: 7.9672e-04
#
# Epoch 00036: val_loss improved from 0.00082 to 0.00080, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 0s 256us/step - loss: 2.3173e-04 - val_loss: 8.1909e-04
#
# Epoch 00037: val_loss did not improve from 0.00080
# Epoch 38/150
# 1712/1712 [==============================] - 0s 260us/step - loss: 2.2699e-04 - val_loss: 8.0624e-04
#
# Epoch 00038: val_loss did not improve from 0.00080
# Epoch 39/150
# 1712/1712 [==============================] - 0s 268us/step - loss: 2.3247e-04 - val_loss: 7.7303e-04
#
# Epoch 00039: val_loss improved from 0.00080 to 0.00077, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 2.2374e-04 - val_loss: 8.4688e-04
#
# Epoch 00040: val_loss did not improve from 0.00077
# Epoch 41/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 2.2229e-04 - val_loss: 8.4225e-04
#
# Epoch 00041: val_loss did not improve from 0.00077
# Epoch 42/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 2.1993e-04 - val_loss: 8.4346e-04
#
# Epoch 00042: val_loss did not improve from 0.00077
# Epoch 43/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 2.1906e-04 - val_loss: 8.2365e-04
#
# Epoch 00043: val_loss did not improve from 0.00077
# Epoch 44/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 2.0661e-04 - val_loss: 8.2521e-04
#
# Epoch 00044: val_loss did not improve from 0.00077
# Epoch 45/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 2.0863e-04 - val_loss: 8.0199e-04
#
# Epoch 00045: val_loss did not improve from 0.00077
# Epoch 46/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 2.0478e-04 - val_loss: 7.7936e-04
#
# Epoch 00046: val_loss did not improve from 0.00077
# Epoch 47/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 2.0828e-04 - val_loss: 7.7633e-04
#
# Epoch 00047: val_loss did not improve from 0.00077
# Epoch 48/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 2.0143e-04 - val_loss: 7.9746e-04
#
# Epoch 00048: val_loss did not improve from 0.00077
# Epoch 49/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.9069e-04 - val_loss: 7.8144e-04
#
# Epoch 00049: val_loss did not improve from 0.00077
# Epoch 50/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.9184e-04 - val_loss: 7.9457e-04
#
# Epoch 00050: val_loss did not improve from 0.00077
# Epoch 51/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 1.9016e-04 - val_loss: 7.8089e-04
#
# Epoch 00051: val_loss did not improve from 0.00077
# Epoch 52/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 1.8344e-04 - val_loss: 7.9656e-04
#
# Epoch 00052: val_loss did not improve from 0.00077
# Epoch 53/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 1.8807e-04 - val_loss: 7.9031e-04
#
# Epoch 00053: val_loss did not improve from 0.00077
# Epoch 54/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.8576e-04 - val_loss: 8.0491e-04
#
# Epoch 00054: val_loss did not improve from 0.00077
# Epoch 55/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 1.8082e-04 - val_loss: 8.0379e-04
#
# Epoch 00055: val_loss did not improve from 0.00077
# Epoch 56/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 1.7161e-04 - val_loss: 8.3475e-04
#
# Epoch 00056: val_loss did not improve from 0.00077
# Epoch 57/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.8212e-04 - val_loss: 8.1984e-04
#
# Epoch 00057: val_loss did not improve from 0.00077
# Epoch 58/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 1.7554e-04 - val_loss: 7.9908e-04
#
# Epoch 00058: val_loss did not improve from 0.00077
# Epoch 59/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 1.7847e-04 - val_loss: 7.9896e-04
#
# Epoch 00059: val_loss did not improve from 0.00077
# Epoch 60/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 1.7345e-04 - val_loss: 7.6302e-04
#
# Epoch 00060: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 61/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 1.7187e-04 - val_loss: 7.5464e-04
#
# Epoch 00061: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 62/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.7638e-04 - val_loss: 7.7901e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.7114e-04 - val_loss: 8.1775e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.6756e-04 - val_loss: 7.5778e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 1.6270e-04 - val_loss: 7.7908e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 1.6008e-04 - val_loss: 7.6935e-04
#
# Epoch 00066: val_loss did not improve from 0.00075
# Epoch 67/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 1.6056e-04 - val_loss: 7.8798e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.5850e-04 - val_loss: 8.0985e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.5707e-04 - val_loss: 7.9598e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 1.5355e-04 - val_loss: 7.8325e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 1.5536e-04 - val_loss: 7.7057e-04
#
# Epoch 00071: val_loss did not improve from 0.00075
# Epoch 72/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 1.5308e-04 - val_loss: 8.0677e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.5613e-04 - val_loss: 8.2488e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.5462e-04 - val_loss: 7.8417e-04
#
# Epoch 00074: val_loss did not improve from 0.00075
# Epoch 75/150
# 1712/1712 [==============================] - 0s 254us/step - loss:
-04
#
# Epoch 00140: val_loss did not improve from 0.00075
# Epoch 141/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 9.4968e-05 - val_loss: 7.8005e-04
#
# Epoch 00141: val_loss did not improve from 0.00075
# Epoch 142/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 9.5599e-05 - val_loss: 7.7633e-04
#
# Epoch 00142: val_loss did not improve from 0.00075
# Epoch 143/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 9.1602e-05 - val_loss: 8.0503e-04
#
# Epoch 00143: val_loss did not improve from 0.00075
# Epoch 144/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 9.0180e-05 - val_loss: 7.8238e-04
#
# Epoch 00144: val_loss did not improve from 0.00075
# Epoch 145/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 9.0245e-05 - val_loss: 7.9512e-04
#
# Epoch 00145: val_loss did not improve from 0.00075
# Epoch 146/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 9.3249e-05 - val_loss: 8.2052e-04
#
# Epoch 00146: val_loss did not improve from 0.00075
# Epoch 147/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 9.1947e-05 - val_loss: 7.8925e-04
#
# Epoch 00147: val_loss did not improve from 0.00075
# Epoch 148/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 9.2618e-05 - val_loss: 8.0340e-04
#
# Epoch 00148: val_loss did not improve from 0.00075
# Epoch 149/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 9.0547e-05 - val_loss: 7.9306e-04
#
# Epoch 00149: val_loss did not improve from 0.00075
# Epoch 150/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 9.0392e-05 - val_loss: 8.0486e-04
#
# Epoch 00150: val_loss did not improve from 0.00075

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = '../facial-keypoints-detection/test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
import imgaug as ia
from imgaug import augmenters as iaa

# %%
points_train.shape
# Out:
# (2140, 30)

# %%
pxy = points_train.reshape(2140,15,2)

# %%
kpl = []
for x, y in zip(pxy[:,:,0], pxy[:,:,1]):
    #print(x,y)
    kpl.append(ia.Keypoint(x=x,y=y))
keypoints=ia.KeypointsOnImage(kpl,shape = imgs_train[0].shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     386                 if cls in self.type_pprinters:
#     387                     # printer registered in self.type_pprinters
# --> 388                     return self.type_pprinters[cls](obj, self, cycle)
#     389                 else:
#     390                     # deferred printer
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in inner(obj, p, cycle)
#     564                 p.text(',')
#     565                 p.breakable()
# --> 566             p.pretty(x)
#     567         if len(obj) == 1 and type(obj) is tuple:
#     568             # Special case for 1-item tuples.
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     403                         if cls is not object \
#     404                                 and callable(cls.__dict__.get('__repr__')):
# --> 405                             return _repr_pprint(obj, self, cycle)
#     406
#     407             return _default_pprint(obj, self, cycle)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     693     """A pprint that just redirects to the normal repr function."""
#     694     # Find newlines and replace them with p.break_()
# --> 695     output = repr(obj)
#     696     lines = output.splitlines()
#     697     with p.group():
#
# ~/anaconda3/lib/python3.7/site-packages/imgaug/augmentables/kps.py in __repr__(self)
#     599
#     600     def __repr__(self):
# --> 601         return self.__str__()
#     602
#     603     def __str__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/imgaug/augmentables/kps.py in __str__(self)
#     602
#     603     def __str__(self):
# --> 604         return "Keypoint(x=%.8f, y=%.8f)" % (self.x, self.y)
#     605
#     606
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
keypoints.shape
# Out:
# (96, 96)

# %%
seq=iaa.Sequential([
    iaa.Fliplr(p=0.5)
    # 旋转10度然后缩放,会影响关键点
])
seq_det = seq.to_deterministic()
image_aug = seq_det.augment_images(imgs_train)
keypoints_aug = seq_det.augment_keypoints(keypoints)

# %%
keypoints
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     403                         if cls is not object \
#     404                                 and callable(cls.__dict__.get('__repr__')):
# --> 405                             return _repr_pprint(obj, self, cycle)
#     406
#     407             return _default_pprint(obj, self, cycle)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     693     """A pprint that just redirects to the normal repr function."""
#     694     # Find newlines and replace them with p.break_()
# --> 695     output = repr(obj)
#     696     lines = output.splitlines()
#     697     with p.group():
#
# ~/anaconda3/lib/python3.7/site-packages/imgaug/augmentables/kps.py in __repr__(self)
#    1481
#    1482     def __repr__(self):
# -> 1483         return self.__str__()
#    1484
#    1485     def __str__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/imgaug/augmentables/kps.py in __str__(self)
#    1485     def __str__(self):
#    1486         return "KeypointsOnImage(%s, shape=%s)" % (
# -> 1487             str(self.keypoints), self.shape)
#
# ~/anaconda3/lib/python3.7/site-packages/imgaug/augmentables/kps.py in __repr__(self)
#     599
#     600     def __repr__(self):
# --> 601         return self.__str__()
#     602
#     603     def __str__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/imgaug/augmentables/kps.py in __str__(self)
#     602
#     603     def __str__(self):
# --> 604         return "Keypoint(x=%.8f, y=%.8f)" % (self.x, self.y)
#     605
#     606
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
imgs_train.shape
# Out:
# (2140, 96, 96)

# %%
image_aug = image_aug+
